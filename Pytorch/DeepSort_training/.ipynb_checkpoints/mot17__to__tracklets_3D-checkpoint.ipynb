# %%
import cv2
import os
import numpy as np
import configparser

# Root directory of the dataset
root_dir = "/home/jovyan/Desktop/MOT17_residual/train/"

# Directory where to save the cropped person data
save_dir = "/home/jovyan/Desktop/test_dataset_residual"

# Loop over the sequences
for directory in os.listdir(root_dir):
    # Load the ground truth file
    if not directory.startswith("MOT17"):
        continue

    # This directory is a MOT17 sequence
    sequence = directory

    # Parse the seqinfo.ini file to get original image dimensions
    config = configparser.ConfigParser()
    config.read(os.path.join(root_dir, sequence, "seqinfo.ini"))
    original_width = int(config["Sequence"]["imWidth"])
    original_height = int(config["Sequence"]["imHeight"])

    gt_file = os.path.join(root_dir, sequence, "gt", "gt.txt")
    gt_data = np.loadtxt(gt_file, delimiter=',')

    # Dictionary to hold person data
    person_data = {}

    # Loop over the ground truth data
    for frame_num, person_id, x, y, w, h, _, _, _ in gt_data:
        # Convert frame_num and person_id to integers
        frame_num = int(frame_num)
        person_id = int(person_id)
        
        if frame_num % 12 == 1:
            continue

        # Load the image file for this frame
        img_file = os.path.join(root_dir, sequence, "img1", f"{frame_num:06}.jpg")
        try:
            img = cv2.imread(img_file)
        except:
            continue  # skip this frame if the image file does not exist

        if img is None:
            continue

        # Get the actual dimensions of the image
        actual_height, actual_width, _ = img.shape

        # Compute scale factors
        scale_y = actual_height / original_height
        scale_x = actual_width / original_width
       # print(scale_y,scale_x)
        # Scale the bounding box coordinates
        x, w = int(x * scale_x), int(w * scale_x)
        y, h = int(y * scale_y), int(h * scale_y)
        
      #  print(f"Scaled bounding box values: x={x}, y={y}, w={w}, h={h}")

        # Crop the image
        x = max(0, x)
        y = max(0, y)
        w = min(w, actual_width - x)
        h = min(h, actual_height - y)

        # If the bounding box has become zero-sized due to corrections, skip it
        if w <= 0 or h <= 0:
            continue

        cropped_img = img[y:y+h, x:x+w]

        # Handle case where cropped_img is empty
        if cropped_img.size == 0:
            print(f"Empty cropped image for frame: {frame_num}{person_id}")
            print(f"Bounding box coordinates: x={x}, y={y}, w={w}, h={h}")
            print(f"Original image size: {img.shape}")

            continue

        # Create a directory to hold this person's data if it doesn't exist yet
        if person_id not in person_data:
            person_data[person_id] = os.path.join(save_dir, sequence, str(person_id))
            os.makedirs(person_data[person_id], exist_ok=True)

        # Save the cropped image
        cv2.imwrite(os.path.join(person_data[person_id], f"{frame_num:06}.jpg"), cropped_img)
# Out:
# [ WARN:0@5788.595] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5790.522] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5792.244] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5795.221] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5807.866] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5821.294] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5833.777] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5836.157] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5839.049] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5875.931] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5888.431] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5901.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5911.930] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5923.214] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5937.365] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5954.421] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5972.514] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5973.427] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5974.002] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5985.935] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@5985.935] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-09-FRCNN/img1/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6009.258] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6128.234] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6224.851] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6225.648] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6229.316] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6246.792] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6247.005] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6247.077] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6247.582] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6248.908] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6250.231] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6251.071] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6252.237] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6252.935] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6253.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6254.345] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6254.984] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6255.190] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6256.507] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6271.730] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6271.730] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-11-FRCNN/img1/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6290.671] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6324.132] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6341.211] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6360.121] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6376.113] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6394.333] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6413.050] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6432.356] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6453.953] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6473.191] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6493.013] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6510.324] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6529.650] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6551.359] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6573.743] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6594.487] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6616.129] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6631.947] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6651.486] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6674.458] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6694.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6717.596] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6733.837] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6754.292] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6774.196] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6796.471] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6818.164] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6836.443] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6855.008] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6871.667] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6887.287] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@6902.928] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-FRCNN/img1/001050.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@
        # Extraire le numéro de séquence du nom du répertoire
        sequence_number = dir_name.split('-')[1]
        
        # Parcourir tous les sous-répertoires dans le répertoire courant
        for subdir_name in os.listdir(dir_path):
            subdir_path = os.path.join(dir_path, subdir_name)
            
            # Vérifier si c'est un répertoire
            if os.path.isdir(subdir_path):
                # Créer un nouveau nom de sous-répertoire préfixé par le numéro de séquence
                new_subdir_name = f"{sequence_number}_{subdir_name}"
                new_subdir_path = os.path.join(dest_dir, new_subdir_name)
                
                # Créer le nouveau sous-répertoire dans le répertoire de destination
                os.makedirs(new_subdir_path, exist_ok=True)
                
                # Parcourir tous les fichiers dans le sous-répertoire courant
                for file_name in os.listdir(subdir_path):
                    file_path = os.path.join(subdir_path, file_name)
                    
                    # Ignore if it's a directory
                    if os.path.isdir(file_path):
                        continue
                    
                    # Créer le chemin vers le nouveau fichier
                    new_file_path = os.path.join(new_subdir_path, file_name)
                    
                    # Copier le fichier dans le nouveau sous-répertoire
                    shutil.copy(file_path, new_file_path)

# %% [markdown]
# ## MOT17_20

# %%
import cv2
import os
import numpy as np
import configparser

# Root directory of the dataset
root_dir = "/home/jovyan/Desktop/MOT17_20_residual/train/"

# Directory where to save the cropped person data
save_dir = "/home/jovyan/Desktop/test_dataset_residual"

# Loop over the sequences
for directory in os.listdir(root_dir):
    # Load the ground truth file
    if not directory.startswith("MOT20"):
        continue

    # This directory is a MOT17 sequence
    sequence = directory

    # Parse the seqinfo.ini file to get original image dimensions
    config = configparser.ConfigParser()
    config.read(os.path.join(root_dir, sequence, "seqinfo.ini"))
    original_width = int(config["Sequence"]["imWidth"])
    original_height = int(config["Sequence"]["imHeight"])

    gt_file = os.path.join(root_dir, sequence, "gt", "gt.txt")
    gt_data = np.loadtxt(gt_file, delimiter=',')

    # Dictionary to hold person data
    person_data = {}

    # Loop over the ground truth data
    for frame_num, person_id, x, y, w, h, _, _, _ in gt_data:
        # Convert frame_num and person_id to integers
        frame_num = int(frame_num)
        person_id = int(person_id)
        
        if frame_num % 12 == 1:
            continue

        # Load the image file for this frame
        img_file = os.path.join(root_dir, sequence, "img1", f"{frame_num:06}.jpg")
        try:
            img = cv2.imread(img_file)
        except:
            continue  # skip this frame if the image file does not exist

        # Handle case where image is None
        if img is None:
            continue

        # Get the actual dimensions of the image
        actual_height, actual_width, _ = img.shape

        # Compute scale factors
        scale_y = actual_height / original_height
        scale_x = actual_width / original_width
       # print(scale_y,scale_x)
        # Scale the bounding box coordinates
        x, w = int(x * scale_x), int(w * scale_x)
        y, h = int(y * scale_y), int(h * scale_y)
        

        # Crop the image
        x = max(0, x)
        y = max(0, y)
        w = min(w, actual_width - x)
        h = min(h, actual_height - y)

        # If the bounding box has become zero-sized due to corrections, skip it
        if w <= 0 or h <= 0:
            continue

        cropped_img = img[y:y+h, x:x+w]

        # Handle case where cropped_img is empty
        if cropped_img.size == 0:
            print(f"Empty cropped image for frame: {frame_num}{person_id}")
            print(f"Bounding box coordinates: x={x}, y={y}, w={w}, h={h}")
            print(f"Original image size: {img.shape}")

            continue

        # Create a directory to hold this person's data if it doesn't exist yet
        if person_id not in person_data:
            person_data[person_id] = os.path.join(save_dir, sequence, str(person_id))
            os.makedirs(person_data[person_id], exist_ok=True)

        # Save the cropped image
        cv2.imwrite(os.path.join(person_data[person_id], f"{frame_num:06}.jpg"), cropped_img)
