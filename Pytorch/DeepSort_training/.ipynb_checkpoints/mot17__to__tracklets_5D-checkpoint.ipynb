# %%
import cv2
import os
import numpy as np
import configparser

# Root directory of the dataset
root_dir = "/home/jovyan/Desktop/ds_dataset/"

# Directory where to save the cropped person data
save_dir = "/home/jovyan/Desktop/test_dataset"

# Loop over the sequences
for directory in os.listdir(root_dir):
    # Load the ground truth file
    if not directory.startswith("MOT17"):
        continue

    # This directory is a MOT17 sequence
    sequence = directory

    # Parse the seqinfo.ini file to get original image dimensions
    config = configparser.ConfigParser()
    config.read(os.path.join(root_dir, sequence, "seqinfo.ini"))
    original_width = int(config["Sequence"]["imWidth"])
    original_height = int(config["Sequence"]["imHeight"])

    gt_file = os.path.join(root_dir, sequence, "gt", "gt.txt")
    gt_data = np.loadtxt(gt_file, delimiter=',')

    # Dictionary to hold person data
    person_data = {}

    # Loop over the ground truth data
    for frame_num, person_id, x, y, w, h, _, _, _ in gt_data:
        # Convert frame_num and person_id to integers
        frame_num = int(frame_num)
        person_id = int(person_id)
        
        if frame_num % 12 == 1:
            continue

        # Load the image file for this frame
        img_file = os.path.join(root_dir, sequence, "residual_images", f"{frame_num:06}.jpg")
        try:
            img = cv2.imread(img_file)
        except:
            continue  # skip this frame if the image file does not exist

        # Handle case where image is None
        if img is None:
            continue
     #   print("frame_num",frame_num)
     #   print(f"Original bounding box values: x={x}, y={y}, w={w}, h={h}")

        # Get the actual dimensions of the image
        actual_height, actual_width, _ = img.shape

        # Compute scale factors
        scale_y = actual_height / original_height
        scale_x = actual_width / original_width

        # Scale the bounding box coordinates
        x, w = int(x * scale_x), int(w * scale_x)
        y, h = int(y * scale_y), int(h * scale_y)
        
      #  print(f"Scaled bounding box values: x={x}, y={y}, w={w}, h={h}")

        # Crop the image
        x = max(0, x)
        y = max(0, y)
        w = min(w, actual_width - x)
        h = min(h, actual_height - y)

        # If the bounding box has become zero-sized due to corrections, skip it
        if w <= 0 or h <= 0:
            continue

        cropped_img = img[y:y+h, x:x+w]

        # Handle case where cropped_img is empty
        if cropped_img.size == 0:
            print(f"Empty cropped image for frame: {frame_num}{person_id}")
            print(f"Bounding box coordinates: x={x}, y={y}, w={w}, h={h}")
            print(f"Original image size: {img.shape}")

            continue

        # Create a directory to hold this person's data if it doesn't exist yet
        if person_id not in person_data:
            person_data[person_id] = os.path.join(save_dir, sequence, str(person_id))
            os.makedirs(person_data[person_id], exist_ok=True)

        # Save the cropped image
        cv2.imwrite(os.path.join(person_data[person_id], f"{frame_num:06}.jpg"), cropped_img)

        # Load the data file for this frame
        data_file = os.path.join(root_dir, sequence, "mv_files", f"{frame_num:06}.npy")
        try:
            data = np.load(data_file)
        except FileNotFoundError:
            continue  # skip this frame if the .npy file does not exist

        # Crop the data
        cropped_data = data[y:y+h, x:x+w, :]

        # Save the cropped data
        np.save(os.path.join(person_data[person_id], f"{frame_num:06}.npy"), cropped_data)
# Out:
# [ WARN:0@37244.034] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37245.379] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37246.184] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37248.582] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37256.837] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37263.842] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37271.779] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37272.683] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37274.591] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37296.942] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37303.482] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37309.952] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37315.647] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37320.935] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37330.278] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37339.784] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37350.882] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37351.140] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37351.437] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37357.128] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37357.128] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-09-FRCNN/residual_images/000525.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.541] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000663.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.541] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000664.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000665.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000666.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000667.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000668.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000669.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.542] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000670.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000671.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000672.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000674.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000675.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000676.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000677.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000678.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000679.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000680.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000681.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000682.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000683.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000684.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000686.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000687.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000688.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000689.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000690.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.544] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000691.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000692.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000693.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000694.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000695.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000696.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000698.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000699.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000700.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.545] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000701.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000702.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000703.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000704.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000705.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000706.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000707.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000708.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000710.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000711.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.546] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000712.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000713.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000714.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000715.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000716.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000717.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000718.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000719.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000720.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000722.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000723.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000724.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000725.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000726.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000727.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000728.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000729.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000730.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.548] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000731.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000732.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000734.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000735.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000736.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000737.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000738.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000739.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000740.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000741.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.549] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000742.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000743.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000744.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000746.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000747.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000748.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000749.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000751.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.550] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000752.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000753.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000754.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000755.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000756.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000758.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000759.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000760.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000761.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000762.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.551] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000763.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000764.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000765.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000766.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000767.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000768.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000770.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000771.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000772.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.552] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000773.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000774.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000775.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000776.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000777.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000778.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000779.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000780.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000782.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000783.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.553] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000784.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000785.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000786.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000787.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000788.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000789.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000790.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000791.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000792.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.554] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000794.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000795.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000796.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000797.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000798.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000799.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000800.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000801.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.555] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000802.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000803.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000804.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000806.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000807.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000808.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000809.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.556] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000810.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000811.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000812.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000813.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000814.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000815.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000816.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.557] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000818.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000819.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000820.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000821.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000822.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000823.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000824.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000825.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000826.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000827.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000828.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000830.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000831.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000832.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000833.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000834.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000835.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000836.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000838.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000839.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000840.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.560] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000842.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000843.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000844.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000845.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000846.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000847.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000848.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.561] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000849.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000850.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000851.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000852.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000854.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000855.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000856.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.562] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000857.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000858.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000859.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000860.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000861.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000862.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000863.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.563] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000864.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000866.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000867.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000868.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000869.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000870.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000871.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000872.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.564] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000873.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000874.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000875.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000876.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000878.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000879.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000880.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000881.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000882.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000883.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000884.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000885.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000886.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000887.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.566] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000888.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000890.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000891.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000892.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000893.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000894.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000895.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.567] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000896.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.568] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000897.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.568] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000898.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.568] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000899.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37368.568] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.371] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000663.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.371] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000664.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.371] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000665.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000666.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000667.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000668.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000669.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000670.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000671.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000672.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000674.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37416.372] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000675.jpg'): can't open/read file: check file path/integrity
# ...
# [ WARN:0@37484.798] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37484.799] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-11-FRCNN/residual_images/000900.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37491.643] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37509.703] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37515.975] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37524.228] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37530.323] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37537.547] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37543.973] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37570.257] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37577.357] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37583.565] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37608.525] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37615.613] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37621.131] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37625.559] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37629.310] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37633.903] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37638.860] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37643.935] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37646.870] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37649.395] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37651.720] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37653.688] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37663.869] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37682.290] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37685.492] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37689.406] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37694.558] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37698.972] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37700.965] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37702.778] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37712.374] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37726.834] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37740.945] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37746.242] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37750.738] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37751.743] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37758.187] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37765.152] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37782.692] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37783.404] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37786.240] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37786.240] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37786.240] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-02-FRCNN/residual_images/000600.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37853.753] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37865.376] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37866.221] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37867.105] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37867.624] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37867.806] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37867.922] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37871.487] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37909.534] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37922.601] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@37922.601] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-05-FRCNN/residual_images/000837.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38002.742] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38004.516] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38027.281] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38028.842] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38030.734] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38087.635] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38125.864] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38141.969] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38164.195] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38194.209] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38203.253] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38203.254] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38203.254] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-13-FRCNN/residual_images/000750.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38213.970] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38224.733] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38258.069] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38264.522] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38331.143] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38377.504] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38386.808] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38394.323] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38403.136] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38449.517] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38451.435] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38454.508] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38455.543] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38462.461] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity
# [ WARN:0@38463.907] global loadsave.cpp:244 findDecoder imread_('/home/jovyan/Desktop/ds_dataset/MOT17-10-FRCNN/residual_images/000654.jpg'): can't open/read file: check file path/integrity

# %%
import os
import shutil

# Le chemin vers votre répertoire principal et le répertoire de destination
main_dir = 'test_dataset'
dest_dir = 'deep_sort_dataset'


os.makedirs(dest_dir, exist_ok=True)

# Parcourir tous les répertoires dans le répertoire principal
for dir_name in os.listdir(main_dir):
    dir_path = os.path.join(main_dir, dir_name)
    
    # Vérifier si c'est un répertoire
    if os.path.isdir(dir_path):
        # Extraire le numéro de séquence du nom du répertoire
        sequence_number = dir_name.split('-')[1]
        
        # Parcourir tous les sous-répertoires dans le répertoire courant
        for subdir_name in os.listdir(dir_path):
            subdir_path = os.path.join(dir_path, subdir_name)
            
            # Vérifier si c'est un répertoire
            if os.path.isdir(subdir_path):
                # Créer un nouveau nom de sous-répertoire préfixé par le numéro de séquence
                new_subdir_name = f"{sequence_number}_{subdir_name}"
                new_subdir_path = os.path.join(dest_dir, new_subdir_name)
                
                # Créer le nouveau sous-répertoire dans le répertoire de destination
                os.makedirs(new_subdir_path, exist_ok=True)
                
                # Parcourir tous les fichiers dans le sous-répertoire courant
                for file_name in os.listdir(subdir_path):
                    file_path = os.path.join(subdir_path, file_name)
                    
                    # Ignore if it's a directory
                    if os.path.isdir(file_path):
                        continue
                    
                    # Créer le chemin vers le nouveau fichier
                    new_file_path = os.path.join(new_subdir_path, file_name)
                    
                    # Copier le fichier dans le nouveau sous-répertoire
                    shutil.copy(file_path, new_file_path)

# %%
import cv2
import numpy as np

PIXEL_MEANS = np.array([[[0.485, 0.456, 0.406]]]) # BGR
PIXEL_STDS = np.array([[[0.229, 0.224, 0.225]]]) # BGR

#mean: [0.485, 0.456, 0.406]
#std: [0.229, 0.224, 0.225]

def denormalize_image(image):
    image = image.astype(np.float32) 
    image *= PIXEL_STDS
    image += PIXEL_MEANS
    return image.astype(np.uint8)

image_path =  "/home/jovyan/Desktop/MOT17_residual/train/MOT17-04-PRIVATE/img1/001049.jpg"
image = cv2.imread(image_path)

# Dé-normaliser l'image
image = denormalize_image(image)

# Convertir de BGR en RGB
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

cv2.imwrite('/home/jovyan/Desktop/image.jpg', image)
# Out:
# True
